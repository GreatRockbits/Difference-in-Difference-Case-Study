# %% [markdown]
# ## How does a merger between airlines affect prices?
# ### Data Preparation
#
#  - using the airline-tickets-usa dataset

# %%
import os
import sys
import warnings

import numpy as np
import pandas as pd

warnings.filterwarnings("ignore")

# %%
# Import the prewritten helper functions
#from py_helper_functions import *

# %% [markdown]
# ## Data Preparation Steps and Descriptive Statistics

# %%
#data = pd.read_stata(data_in + "originfinal-panel.dta")
data = pd.read_stata("https://osf.io/zw2h9/download")

# %%
data = data.loc[lambda x: (x["year"] == 2011) | (x["year"] == 2016)].reset_index(
    drop=True
)

# %%
# * create total number of passengers from shares
# * so we can get aggreagate shares

data["ptotalAA"] = data["shareAA"] * data["passengers"]
data["ptotalUS"] = data["shareUS"] * data["passengers"]
data["ptotallargest"] = data["sharelargest"] * data["passengers"]

data_agg = (
    data.groupby(["origin", "finaldest", "return", "year"])
    .agg(
        airports=("airports", "first"),
        return_sym=("return_sym", "first"),
        stops=("stops", "first"),
        ptotalAA=("ptotalAA", sum),
        ptotalUS=("ptotalUS", sum),
        ptotallargest=("ptotallargest", sum),
        passengers=("passengers", sum),
        itinfare=("itinfare", sum),
    )
    .reset_index()
)

# %%
data_agg["after"] = np.where(data_agg["year"] == 2016, 1, 0)
data_agg["before"] = np.where(data_agg["year"] == 2011, 1, 0)
data_agg["avgprice"] = data_agg["itinfare"] / data_agg["passengers"]
data_agg["shareAA"] = data_agg["ptotalAA"] / data_agg["passengers"]
data_agg["shareUS"] = data_agg["ptotalUS"] / data_agg["passengers"]
data_agg["sharelargest"] = data_agg["ptotallargest"] / data_agg["passengers"]
data_agg["AA"] = np.where(data_agg["shareAA"] > 0, 1, 0)
data_agg["US"] = np.where(data_agg["shareUS"] > 0, 1, 0)
data_agg["US"] = np.where(data_agg["shareUS"] > 0, 1, 0)
data_agg["AA_and_US"] = np.where(
    (data_agg["shareAA"] > 0) & (data_agg["shareUS"]) > 0, 1, 0
)
data_agg["AA_or_US"] = np.where(
    (data_agg["shareAA"] > 0) | (data_agg["shareUS"]) > 0, 1, 0
)

# %%
# create numeric ID for market
data_agg["market"] = (
    data_agg["origin"]
    + "_"
    + data_agg["finaldest"]
    + "_"
    + data_agg["return"].apply(str)
)

# %%
# passengers before and after
data_agg["pass_bef_id"] = np.where(
    data_agg["before"] == 1, data_agg["passengers"], np.nan
)
data_agg["pass_aft_id"] = np.where(
    data_agg["after"] == 1, data_agg["passengers"], np.nan
)

data_agg["pass_bef"] = data_agg.groupby("market")["pass_bef_id"].transform(np.nanmean)
data_agg["pass_aft"] = data_agg.groupby("market")["pass_aft_id"].transform(np.nanmean)

# %%
# balanced vs unbalanced part of panel
data_agg["balanced"] = data_agg.groupby("market")["origin"].transform("count") == 2

# %%
data_agg.groupby("balanced").agg(
    sum_passengers=("passengers", sum), n=("origin", "count")
)
# Out:
#           sum_passengers       n
# balanced
# False             561060   51516
# True            54136421  226094

# %% [markdown]
# ### Define treated and untreated markets
# - treated: both AA and US present in the before period
# - untreated: neither AA nor US present in the before period OR only AA or only US in before period
#
# This definition of treated and untreated markets left some markets neither treated nor untreated: those with only American or only US Airways present in 2011. For the main analysis we **kept these in the data as untreated**.

# %%
data_agg = data_agg.merge(
    data_agg.loc[lambda x: x["balanced"] == 1]
    .assign(
        treated=lambda x: (x["AA_and_US"] == 1) & (x["before"] == 1),
        untreated=lambda x: (x["AA_and_US"] == 0) & (x["before"] == 1),
        smallmkt=lambda x: (x["passengers"] < 5000) & (x["before"] == 1),
    )
    .groupby("market")
    .agg(
        treated=("treated", max),
        untreated=("untreated", max),
        smallmkt=("smallmkt", max),
    )
    .reset_index(),
    on="market",
    how="left",
)

# %%
data_agg["lnavgp"] = np.where(
    np.isinf(np.log(data_agg["avgprice"])), np.nan, np.log(data_agg["avgprice"])
)
data_agg["d_lnavgp"] = data_agg.groupby("market")["lnavgp"].transform("diff")

# %% [markdown]
# ## Describe

# %%
# describe yearly data
data_agg[["year", "passengers"]].groupby("year").describe(
    percentiles=[0.25, 0.5, 0.75, 0.9]
).round(0)
# Out:
#      passengers
#           count   mean     std  min  25%  50%   75%    90%      max
# year
# 2011   141712.0  170.0   980.0  1.0  2.0  7.0  37.0  205.0  39853.0
# 2016   135898.0  225.0  1270.0  1.0  2.0  8.0  45.0  245.0  46881.0

# %%
data_agg.query('(origin=="JFK") & (finaldest=="LAX")')[
    ["market", "origin", "finaldest", "return", "year", "passengers"]
]
# Out:
#            market origin finaldest  return  year  passengers
# 139047  JFK_LAX_0    JFK       LAX       0  2011       31312
# 139048  JFK_LAX_0    JFK       LAX       0  2016       46881
# 139049  JFK_LAX_1    JFK       LAX       1  2011       37861
# 139050  JFK_LAX_1    JFK       LAX       1  2016       41927

# %%
data_agg.query("year == 2011")[["smallmkt", "passengers"]].groupby(
    "smallmkt"
).describe().round(0)
# Out:
#          passengers
#               count    mean     std     min     25%     50%      75%      max
# smallmkt
# False         887.0  9813.0  5748.0  5003.0  5987.0  7908.0  11278.0  39853.0
# True       112160.0   136.0   456.0     1.0     3.0    12.0     55.0   4994.0

# %%
# describe balanced
data_agg.groupby(["year", "balanced"])["passengers"].describe(percentiles=[]).round(1)
# Out:
#                   count   mean     std  min   50%      max
# year balanced
# 2011 False      28665.0    3.6    23.8  1.0   1.0   2051.0
#      True      113047.0  211.9  1092.7  1.0  12.0  39853.0
# 2016 False      22851.0   20.0   178.1  1.0   1.0   4798.0
#      True      113047.0  267.0  1386.3  1.0  13.0  46881.0

# %%
# describe treatment
data_agg.groupby(["year", "treated", "untreated"]).describe(percentiles=[]).round(1).T
# Out:
# year                2011               2016
# treated            False    True      False    True
# untreated          True     False     True     False
# return   count  101418.0  11629.0  101418.0  11629.0
#          mean        0.5      0.5       0.5      0.5
#          std         0.5      0.5       0.5      0.5
#          min         0.0      0.0       0.0      0.0
#          50%         1.0      0.0       1.0      0.0
# ...                  ...      ...       ...      ...
# d_lnavgp mean        NaN      NaN       0.1      0.0
#          std         NaN      NaN       0.7      0.3
#          min         NaN      NaN      -6.4     -2.4
#          50%         NaN      NaN       0.1      0.0
#          max         NaN      NaN       6.5      2.3
#
# [150 rows x 4 columns]

# %%
# describe outcome
data_agg.query("before == 1")["avgprice"].describe().round(2)
# Out:
# count    141712.00
# mean        455.75
# std         276.49
# min           0.00
# 25%         285.50
# 50%         413.40
# 75%         561.03
# max        6054.00
# Name: avgprice, dtype: float64

# %%
data_agg.query("avgprice == 0")["passengers"].describe().round(2)
# Out:
# count    843.00
# mean       1.08
# std        0.31
# min        1.00
# 25%        1.00
# 50%        1.00
# 75%        1.00
# max        3.00
# Name: passengers, dtype: float64

# %%
data_agg.to_pickle("airline-workfile.pkl")

# %%
descriptive_stats_all = data_agg.describe(percentiles=[0.25, 0.5, 0.75]).round(2)

# %%
descriptive_stats_all.T
# Out:
#                   count      mean        std      min      25%      50%  \
# return         277610.0      0.52       0.50     0.00     0.00     1.00
# year           277610.0   2013.45       2.50  2011.00  2011.00  2011.00
# airports       277610.0      4.51       1.43     2.00     3.00     5.00
# return_sym     145027.0      0.78       0.41     0.00     1.00     1.00
# stops          277610.0      1.30       0.52     0.00     1.00     1.00
# ptotalAA       277610.0     26.54     305.59     0.00     0.00     0.00
# ptotalUS       277610.0      6.26     108.71     0.00     0.00     0.00
# ptotallargest  277610.0    125.10     693.56     1.00     2.00     6.00
# passengers     277610.0    197.03    1131.39     1.00     2.00     7.00
# itinfare       277610.0  36930.82  155802.90     0.00   978.00  3355.00
# after          277610.0      0.49       0.50     0.00     0.00     0.00
# before         277610.0      0.51       0.50     0.00     0.00     1.00
# avgprice       277610.0    461.91     272.57     0.00   294.40   425.33
# shareAA        277610.0      0.10       0.24     0.00     0.00     0.00
# shareUS        277610.0      0.03       0.13     0.00     0.00     0.00
# sharelargest   277610.0      0.84       0.21     0.14     0.67     1.00
# AA             277610.0      0.25       0.43     0.00     0.00     0.00
# US             277610.0      0.10       0.30     0.00     0.00     0.00
# AA_and_US      277610.0      0.04       0.20     0.00     0.00     0.00
# AA_or_US       277610.0      0.31       0.46     0.00     0.00     0.00
# pass_bef_id    141712.0    169.73     979.62     1.00     2.00     7.00
# pass_aft_id    135898.0    225.49    1269.87     1.00     2.00     8.00
# pass_bef       254759.0    188.43    1031.56     1.00     2.00     9.00
# pass_aft       248945.0    244.35    1324.17     1.00     3.00    10.00
# lnavgp         276767.0      5.95       0.74    -0.12     5.69     6.05
# d_lnavgp       112632.0      0.06       0.67    -6.40    -0.18     0.06
#
#                     75%          max
# return             1.00         1.00
# year            2016.00      2016.00
# airports           5.00         9.00
# return_sym         1.00         1.00
# stops              2.00         3.00
# ptotalAA           1.00     24782.00
# ptotalUS           0.00     19264.00
# ptotallargest     28.00     28735.00
# passengers        41.00     46881.00
# itinfare       15796.75  10189694.00
# after              1.00         1.00
# before             1.00         1.00
# avgprice         567.55      8975.00
# shareAA            0.00         1.00
# shareUS            0.00         1.00
# sharelargest       1.00         1.00
# AA                 1.00         1.00
# US                 0.00         1.00
# AA_and_US          0.00         1.00
# AA_or_US           1.00         1.00
# pass_bef_id       37.00     39853.00
# pass_aft_id       45.00     46881.00
# pass_bef          46.00     39853.00
# pass_aft          54.00     46881.00
# lnavgp             6.34         9.10
# d_lnavgp           0.27         6.46

# %%
latex_output_all = descriptive_stats_all.T.to_latex()

# %%
latex_output_all
# Out:
# '\\begin{tabular}{lrrrrrrrr}\n\\toprule\n & count & mean & std & min & 25% & 50% & 75% & max \\\\\n\\midrule\nreturn & 277610.000000 & 0.520000 & 0.500000 & 0.000000 & 0.000000 & 1.000000 & 1.000000 & 1.000000 \\\\\nyear & 277610.000000 & 2013.450000 & 2.500000 & 2011.000000 & 2011.000000 & 2011.000000 & 2016.000000 & 2016.000000 \\\\\nairports & 277610.000000 & 4.510000 & 1.430000 & 2.000000 & 3.000000 & 5.000000 & 5.000000 & 9.000000 \\\\\nreturn_sym & 145027.000000 & 0.780000 & 0.410000 & 0.000000 & 1.000000 & 1.000000 & 1.000000 & 1.000000 \\\\\nstops & 277610.000000 & 1.300000 & 0.520000 & 0.000000 & 1.000000 & 1.000000 & 2.000000 & 3.000000 \\\\\nptotalAA & 277610.000000 & 26.540000 & 305.590000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 & 24782.000000 \\\\\nptotalUS & 277610.000000 & 6.260000 & 108.710000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 19264.000000 \\\\\nptotallargest & 277610.000000 & 125.100000 & 693.560000 & 1.000000 & 2.000000 & 6.000000 & 28.000000 & 28735.000000 \\\\\npassengers & 277610.000000 & 197.030000 & 1131.390000 & 1.000000 & 2.000000 & 7.000000 & 41.000000 & 46881.000000 \\\\\nitinfare & 277610.000000 & 36930.820000 & 155802.900000 & 0.000000 & 978.000000 & 3355.000000 & 15796.750000 & 10189694.000000 \\\\\nafter & 277610.000000 & 0.490000 & 0.500000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 & 1.000000 \\\\\nbefore & 277610.000000 & 0.510000 & 0.500000 & 0.000000 & 0.000000 & 1.000000 & 1.000000 & 1.000000 \\\\\navgprice & 277610.000000 & 461.910000 & 272.570000 & 0.000000 & 294.400000 & 425.330000 & 567.550000 & 8975.000000 \\\\\nshareAA & 277610.000000 & 0.100000 & 0.240000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 \\\\\nshareUS & 277610.000000 & 0.030000 & 0.130000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 \\\\\nsharelargest & 277610.000000 & 0.840000 & 0.210000 & 0.140000 & 0.670000 & 1.000000 & 1.000000 & 1.000000 \\\\\nAA & 277610.000000 & 0.250000 & 0.430000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 & 1.000000 \\\\\nUS & 277610.000000 & 0.100000 & 0.300000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 \\\\\nAA_and_US & 277610.000000 & 0.040000 & 0.200000 & 0.000000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 \\\\\nAA_or_US & 277610.000000 & 0.310000 & 0.460000 & 0.000000 & 0.000000 & 0.000000 & 1.000000 & 1.000000 \\\\\npass_bef_id & 141712.000000 & 169.730000 & 979.620000 & 1.000000 & 2.000000 & 7.000000 & 37.000000 & 39853.000000 \\\\\npass_aft_id & 135898.000000 & 225.490000 & 1269.870000 & 1.000000 & 2.000000 & 8.000000 & 45.000000 & 46881.000000 \\\\\npass_bef & 254759.000000 & 188.430000 & 1031.560000 & 1.000000 & 2.000000 & 9.000000 & 46.000000 & 39853.000000 \\\\\npass_aft & 248945.000000 & 244.350000 & 1324.170000 & 1.000000 & 3.000000 & 10.000000 & 54.000000 & 46881.000000 \\\\\nlnavgp & 276767.000000 & 5.950000 & 0.740000 & -0.120000 & 5.690000 & 6.050000 & 6.340000 & 9.100000 \\\\\nd_lnavgp & 112632.000000 & 0.060000 & 0.670000 & -6.400000 & -0.180000 & 0.060000 & 0.270000 & 6.460000 \\\\\n\\bottomrule\n\\end{tabular}\n'
